# %% [markdown]
# # Unit 01
# ---
#
# Date: 2017-02-09

# %%
# sum_square

# %%
# sum_sqaure -> calculate square of sum of two numbers
54 + 73
# Out:
# 127

# %% [markdown]
# **+** is addition operator

# %%
127 ** 2
# Out:
# 16129

# %% [markdown]
# __\*\*__ is power operator

# %%
first_num = 59
second_num = 87

# %% [markdown]
# **first_num** and **second_num** are called a *variable*

# %%
square_of = (first_num + second_num) ** 2

# %%
print(square_of)
# Out:
# 21316

# %%
# 3.14 is a float
pi = 3.14

# %%
area_of_circle = 2 * pi * (3 ** 2)

# %%
print(area_of_circle)
# Out:
# 56.52

# %% [markdown]
# Python automatically converts **integers** ( like *2* and *3* above )
# to **float** ( like *3.14* )
#
# Such conversions are called type conversion ( or *type casting* )

# %%
name = 'Harry Potter'

# %%
address = "London"

# %%
name + address
# Out:
# 'Harry PotterLondon'

# %% [markdown]
# adding two strings together is called **Concatenation**

# %%
name * address
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-fabec2ae4473> in <module>()
# ----> 1 name * address
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
name * 4
# Out:
# 'Harry PotterHarry PotterHarry PotterHarry Potter'

# %% [markdown]
# Incase of string __*__ is called *Repitition operator*

# %%
name * 2.3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-5a56ada40a02> in <module>()
# ----> 1 name * 2.3
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
78 - 90
# Out:
# -12

# %%
30 - 12.2
# Out:
# 17.8

# %%
# Division
2 / 3
# Out:
# 0.6666666666666666

# %% [markdown]
# - Real Division

# %%
2 // 3
# Out:
# 0

# %% [markdown]
# - Integer Division

# %%
2.0 // 3
# Out:
# 0.0

# %%
float(2)
# Out:
# 2.0

# %% [markdown]
# - Explicit conversion

# %%
int(3.9)
# Out:
# 3

# %%
str(2)
# Out:
# '2'

# %% [markdown]
# Remainder Operator

# %%
8 % 3
# Out:
# 2

# %% [markdown]
# **H/W**
# - Addition
# - Substraction
# - Division
#     - Float
#     - Integer
# - Remainder
# - Power
