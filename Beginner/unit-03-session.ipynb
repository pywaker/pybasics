# %% [markdown]
# # Session 3
# ---
#
# - For/While loops
# - If/Else statements
# - With statement

# %%
languages = {
    'scripting': ['Shell', 'Python', 'Perl'],
    'object oriented': ['C++', 'Java', 'Python'],
    'compiled': ['C', 'C++', 'Java']
}

# %% [markdown]
# - languages --> dict
# - 3 keys in languages dict
# - each value is list of langs

# %%
languages.keys()
# Out:
# dict_keys(['object oriented', 'compiled', 'scripting'])

# %%
languages.keys()[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-0e95d6b4f323> in <module>()
# ----> 1 languages.keys()[0]
#
# TypeError: 'dict_keys' object does not support indexing

# %%
for category in languages.keys():
    print(category)
# Out:
# object oriented
# compiled
# scripting

# %%
for item in languages.values():
    print(item)
# Out:
# ['C++', 'Java', 'Python']
# ['C', 'C++', 'Java']
# ['Shell', 'Python', 'Perl']

# %%
for cat, lang in languages.items():
    print(cat, '...', lang)
# Out:
# object oriented ... ['C++', 'Java', 'Python']
# compiled ... ['C', 'C++', 'Java']
# scripting ... ['Shell', 'Python', 'Perl']

# %%
firstname = 'Hello'
lastname = 'world'

# %%
firstname, lastname = 'Hello', 'world'
firstname
# Out:
# 'Hello'

# %%
a, b, c = 0, 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-7d060707a3ea> in <module>()
# ----> 1 a, b, c = 0, 1
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
a, b = 1, 4, 7
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-8b2ed08cee59> in <module>()
# ----> 1 a, b = 1, 4, 7
#
# ValueError: too many values to unpack (expected 2)

# %%
(4, 6, 7)
# Out:
#   File "<ipython-input-12-d72c16c8a9b5>", line 1
#     *(4, 6, 7)
#               ^
# SyntaxError: can't use starred expression here

# %%
m, n = (88, 99)
m
# Out:
# 88

# %%
for item in languages.items():
    print(item)
    cat, lang = item #'object oriented', ['C++', 'Java', 'Python']
    print(cat, '....')
# Out:
# ('object oriented', ['C++', 'Java', 'Python'])
# object oriented ....
# ('compiled', ['C', 'C++', 'Java'])
# compiled ....
# ('scripting', ['Shell', 'Python', 'Perl'])
# scripting ....

# %%
for cat, lang in languages.items():
    print(cat, '....')
# Out:
# object oriented ....
# compiled ....
# scripting ....

# %%
languages.items()
# Out:
# dict_items([('object oriented', ['C++', 'Java', 'Python']), ('compiled', ['C', 'C++', 'Java']), ('scripting', ['Shell', 'Python', 'Perl'])])

# %%
for item in [1, 2, 3, 4]:
    print("The value is {}".format(item))
# Out:
# The value is 1
# The value is 2
# The value is 3
# The value is 4

# %%
for item in [('a', 1), ('b', 2), ('c', 3), ('d', 4)]:
    print("The value is {}".format(item))
# Out:
# The value is ('a', 1)
# The value is ('b', 2)
# The value is ('c', 3)
# The value is ('d', 4)

# %%
for item in [('a', 1), ('b', 2), ('c', 3), ('d', 4)]:
    print("The key is {} value is {}".format(item[0], 
                                             item[1]))
# Out:
# The key is a value is 1
# The key is b value is 2
# The key is c value is 3
# The key is d value is 4

# %%
for item in [('a', 1), ('b', 2), ('c', 3), ('d', 4)]:
    key, val = item[0], item[1]
    print("The key is {} value is {}".format(key, 
                                             val))
# Out:
# The key is a value is 1
# The key is b value is 2
# The key is c value is 3
# The key is d value is 4

# %%
for item in [('a', 1), ('b', 2), ('c', 3), ('d', 4)]:
    key, val = (item[0], item[1])
    print("The key is {} value is {}".format(key, 
                                              val))
# Out:
# The key is a value is 1
# The key is b value is 2
# The key is c value is 3
# The key is d value is 4

# %%
for item in [('a', 1), ('b', 2), ('c', 3), ('d', 4)]:
#     print((item[0], item[1]))
#     print(item)
    key, val = item
    print("The key is {} value is {}".format(key, 
                                              val))
# Out:
# The key is a value is 1
# The key is b value is 2
# The key is c value is 3
# The key is d value is 4

# %%
for key, val in [('a', 1), ('b', 2), ('c', 3), ('d', 4)]:
    print("The key is {} value is {}".format(key, 
                                              val))
# Out:
# The key is a value is 1
# The key is b value is 2
# The key is c value is 3
# The key is d value is 4

# %%
for cat, langs in languages.items():
    if 'Python' in langs:
        print('Python is in {}'.format(cat))
    else:
        print('Python is not in {}'.format(cat))
# Out:
# Python is in object oriented
# Python is not in compiled
# Python is in scripting

# %%
for cat, langs in languages.items():
    if 'Python' in langs and 'Perl' in langs:
        print('Python and Perl are in {}'.format(cat))
    elif 'Python' in langs:
        print('Python is in {}'.format(cat))
    else:
        print('Python is not in {}'.format(cat))
# Out:
# Python is in object oriented
# Python is not in compiled
# Python and Perl are in scripting

# %%
0 or 1
# Out:
# 1

# %%
1 or 2
# Out:
# 1

# %%
bool(0)
# Out:
# False

# %%
a = 0 or 1

# %%
b = 0 if 0 else 5

# %%
b
# Out:
# 5

# %%
b = None
if 0:
    b = 0
else:
    b = 5
b
# Out:
# 5

# %%
bool([])
# Out:
# False

# %%
lst = [1, 2, 3]
if lst:
    print(lst)
# Out:
# [1, 2, 3]

# %%
'' == False
# Out:
# False

# %%
bool('') == False
# Out:
# True

# %%
'a' in 'apple'
# Out:
# True

# %%
'a' is 'a'
# Out:
# True

# %%
'a' is str
# Out:
# False

# %%
'a' is 'b'
# Out:
# False

# %%
'a' is str('a')
# Out:
# True

# %%
2 < 3
# Out:
# True

# %%
1 < 2 < 3
# Out:
# True
